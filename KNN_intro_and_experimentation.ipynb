# %% [markdown]
# <a href="https://colab.research.google.com/github/awaaat/Machine_learning-Deep_learning/blob/main/KNN_intro_and_experimentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets, neighbors
from mlxtend.plotting import plot_decision_regions

# %%
# Load dataset
iris = datasets.load_iris(as_frame=True)
X = iris.data[["sepal length (cm)", "sepal width (cm)"]] # we only take two features for easy visualization
y = iris.target # 0,1,2 --> species of iris flower

X.join(y)
# Out:
#      sepal length (cm)  sepal width (cm)  target
# 0                  5.1               3.5       0
# 1                  4.9               3.0       0
# 2                  4.7               3.2       0
# 3                  4.6               3.1       0
# 4                  5.0               3.6       0
# ..                 ...               ...     ...
# 145                6.7               3.0       2
# 146                6.3               2.5       2
# 147                6.5               3.0       2
# 148                6.2               3.4       2
# 149                5.9               3.0       2
#
# [150 rows x 3 columns]

# %%
def knn_comparison(data, k):
  x = data[["sepal length (cm)", "sepal width (cm)"]].values # we only take these two features for easy visualization
  y = data['target'].astype(int).values
  clf = neighbors.KNeighborsClassifier(n_neighbors=k)
  clf.fit(x, y) # Plotting decision region

  # Adding axes annotations
  plot_decision_regions(x, y, clf=clf, legend=2)
  plt.xlabel("sepal length (cm)")
  plt.ylabel("sepal width (cm)")
  plt.title('KNN with K=' + str(k))
  plt.show()

# %%
k = 1  # set the hyperparameter k

knn_comparison(X.join(y), k)
