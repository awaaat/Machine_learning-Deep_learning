# %% [markdown]
# <a href="https://colab.research.google.com/github/awaaat/Machine_learning-Deep_learning/blob/main/Multi_Layer_Perceptron_Learning_in_Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
import matplotlib.pyplot as plt

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")

# %%
#We normalize by deviding with 255
X_train = (X_train/255)
X_test = (X_test/255)

# %%
print("Feature matrix:", X_train.shape)
print("Target matrix:", X_test.shape)
print("Feature matrix:", y_train.shape)
print("Target matrix:", y_test.shape)
# Out:
# Feature matrix: (60000, 28, 28)
# Target matrix: (10000, 28, 28)
# Feature matrix: (60000,)
# Target matrix: (10000,)

# %%
#Vuisualize, Visualize, Visualize
fig, ax = plt.subplots(10, 10)
k = 0
for i in range(10):
  for j in range(10):
    ax[i][j].imshow(X_train[k].reshape(28,28), aspect = "auto")
    k+=1
  plt.show()

# %% [markdown]
# # Form the Input, hidden, and output layers.

# %%
model = Sequential([
    # reshape 28 row * 28 column data to 28*28 rows
    Flatten(input_shape = (28, 28)),
    #Let's have layer 1
    Dense(256, activation = "sigmoid"),
    #Let's have layer 2
    Dense(128, activation = "sigmoid"),
    #Let's have layer 3 which is an output layer
    Dense(10, activation = "sigmoid")
])

# %% [markdown]
# #Let us compile our model

# %%
model.compile(
    optimizer = "adam",
    loss = "sparse_categorical_crossentropy",
    metrics = ["accuracy"]
)

# %% [markdown]
# #Fitting the model

# %%
model.fit(X_train, y_train, epochs = 5, validation_split=0.2)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 10s 7ms/step - loss: 0.0427 - accuracy: 0.9868 - val_loss: 0.0392 - val_accuracy: 0.9882
# Epoch 2/5
# 1500/1500 [==============================] - 11s 8ms/step - loss: 0.0306 - accuracy: 0.9910 - val_loss: 0.0428 - val_accuracy: 0.9864
# Epoch 3/5
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0233 - accuracy: 0.9935 - val_loss: 0.0438 - val_accuracy: 0.9865
# Epoch 4/5
# 1500/1500 [==============================] - 12s 8ms/step - loss: 0.0177 - accuracy: 0.9949 - val_loss: 0.0522 - val_accuracy: 0.9834
# Epoch 5/5
# 1500/1500 [==============================] - 11s 7ms/step - loss: 0.0133 - accuracy: 0.9963 - val_loss: 0.0459 - val_accuracy: 0.9861

# %%
results = model.evaluate(X_test, y_test, verbose = 0)
print('test loss, test acc:', results)
# Out:
# test loss, test acc: [0.0730549544095993, 0.9801999926567078]
