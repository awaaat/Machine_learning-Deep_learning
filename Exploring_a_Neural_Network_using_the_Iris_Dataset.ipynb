# %% [markdown]
# <a href="https://colab.research.google.com/github/awaaat/Machine_learning-Deep_learning/blob/main/Exploring_a_Neural_Network_using_the_Iris_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier

# Load the iris dataset
iris = load_iris()

# look at the four (4) features
pd.DataFrame(iris.data, columns=iris.feature_names)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.25)

# %%
# Create a neural network
#  hidden_layer_sizes=(10,5,15) -- this would mean there are 3 layers, with the number of neurons in layer 1 at 10, layer 2 at 5, and layer 3 at 15
clf = MLPClassifier(hidden_layer_sizes=(10), activation='relu', solver='adam', max_iter=1000)

# Fit the neural network to the iris dataset
clf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=10, max_iter=1000)

# %%
# output all of the weights for every node connection, with the first index as layer, second index as neuron within layer
for i in range(len(clf.coefs_)):
    number_neurons_in_layer = clf.coefs_[i].shape[1]
    for j in range(number_neurons_in_layer):
        weights = clf.coefs_[i][:,j]
        print(str(i)+", "+str(j)+": ", weights, end=", ")
        print()
    print()
# Out:
# 0, 0:  [-0.00470086  0.85232383 -0.05615186 -0.99266967],
# 0, 1:  [ 0.78990782  0.27460976 -1.01073495 -0.99672792],
# 0, 2:  [-0.02179774 -0.24126534 -0.01483611 -0.03723111],
# 0, 3:  [ 0.09255638  0.60941727 -0.5955501  -0.63694979],
# 0, 4:  [ 0.34113726 -0.46879041  1.10603577  0.41038209],
# 0, 5:  [ 0.88500305  0.25343803 -0.92855381 -0.35705093],
# 0, 6:  [ 0.44540154  0.81572611 -0.79661799 -0.89147645],
# 0, 7:  [-0.00718024 -0.00090392 -0.04673376 -0.00039895],
# 0, 8:  [-0.27954454  0.34635114  0.84346212  0.84056752],
# 0, 9:  [0.37070213 0.15999768 0.70333602 0.19481091],
#
# 1, 0:  [ 5.03503224e-01  1.00099265e+00 -8.27229281e-02  9.62881650e-01
#  -9.42248054e-01 -5.53544653e-02  8.97076896e-01  1.55704759e-05
#  -2.57058919e-01 -3.06876163e-01],
# 1, 1:  [ 0.13924256 -0.50001256 -0.0011452  -0.78249102 -0.46829266  0.121627
#   0.94968133 -0.06182858 -0.68970606  0.16850081],
# 1, 2:  [-1.87411277e-01 -3.77475251e-02  2.45381472e-05 -5.24858654e-01
# ...

# %% [markdown]
# 1. Explain the above output in your own words.
# 2. What do the numbers on each line represent?
# 3. Why are there 4 values for each neuron in the first hidden layer?
# 4. Why are there 10 values for each neuron in the output layer?

# %%
# calculate the TEST accuracy
accuracy_score(y_test, clf.predict(X_test))
# Out:
# 1.0
